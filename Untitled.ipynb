# %%
import os
import pandas as pd

def merge_csv_files(root_directory, output_file):
    all_data = []
    
    ################################# Traverse all folders and subfolders
    for folder, _, files in os.walk(root_directory):
        for file in files:
            if file.endswith(".csv"):  ### Ensure only CSV files are processed
                file_path = os.path.join(folder, file)
                print(f"Processing: {file_path}")
                
                df = pd.read_csv(file_path)
                all_data.append(df)
    
    ### Concatenate all DataFrames
    if all_data:
        merged_df = pd.concat(all_data, ignore_index=True)
        merged_df.to_csv(output_file, index=False)
        print(f"Merged CSV saved as {output_file}")
    else:
        print("No CSV files found!")

### Example usage
root_directory = r"D:\DelhiElectricity\delhi_dispatch\data"  ### Change this to your root folder containing subfolders
output_file = "merged_output.csv"  ### Change the output file name as needed
merge_csv_files(root_directory, output_file)
# Out:
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_01_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_02_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_03_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_04_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_05_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_06_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_07_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_08_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_09_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_10_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_11_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_12_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_13_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_14_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_15_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_16_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_17_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_18_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_19_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_20_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_21_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_22_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_23_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_24_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_25_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_26_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_27_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_28_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_29_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\april\delhi_30_04_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_01_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_02_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_03_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_04_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_05_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_06_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_07_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_08_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_09_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_10_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_11_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_12_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_13_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_14_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_15_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_16_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_17_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_18_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_19_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_20_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_21_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_22_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_23_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_24_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_25_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_26_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_27_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_28_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_29_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_30_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\august\delhi_31_08_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\december\delhi_01_12_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\december\delhi_02_12_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\december\delhi_03_12_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\december\delhi_04_12_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\december\delhi_05_12_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\december\delhi_06_12_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\december\delhi_07_12_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\december\delhi_08_12_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\december\delhi_09_12_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\december\delhi_10_12_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_01_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_02_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_03_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_04_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_05_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_06_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_07_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_08_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_09_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_10_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_11_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_12_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_13_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_14_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_15_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_16_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_17_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_18_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_19_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_20_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_21_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_22_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_23_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_24_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_25_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_26_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_27_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\february\delhi_28_02_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_01_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_02_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_03_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_04_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_05_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_06_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_07_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_08_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_09_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_10_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_11_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_12_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_13_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_14_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_15_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_16_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_17_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_18_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_19_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_20_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_21_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_22_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_23_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_24_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_25_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_26_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_27_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_28_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_29_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_30_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\january\delhi_31_01_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_01_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_02_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_03_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_04_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_05_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_06_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_07_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_08_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_09_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_10_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_11_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_12_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_13_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_14_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_15_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_16_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_17_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_18_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_19_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_20_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_21_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_22_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_23_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_24_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_25_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_26_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_27_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_28_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_29_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_30_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\july\delhi_31_07_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_01_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_02_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_03_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_04_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_05_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_06_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_07_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_08_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_09_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_10_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_11_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_12_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_13_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_14_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_15_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_16_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_17_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_18_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_19_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_20_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_21_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_22_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_23_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_24_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_25_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_26_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_27_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_28_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_29_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\june\delhi_30_06_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_01_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_02_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_03_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_04_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_05_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_06_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_07_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_08_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_09_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_10_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_11_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_12_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_13_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_14_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_15_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_16_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_17_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_18_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_19_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_20_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_21_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_22_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_23_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_24_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_25_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_26_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_27_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_28_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_29_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_30_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\march\delhi_31_03_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_01_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_02_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_03_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_04_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_05_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_06_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_07_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_08_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_09_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_10_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_11_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_12_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_13_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_14_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_15_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_16_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_17_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_18_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_19_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_20_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_21_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_22_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_23_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_24_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_25_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_26_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_27_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_28_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_29_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_30_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\may\delhi_31_05_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_01_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_02_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_03_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_04_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_05_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_06_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_07_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_08_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_09_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_10_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_11_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_12_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_13_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_14_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_15_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_16_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_17_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_18_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_19_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_20_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_21_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_22_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_23_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_24_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_25_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_26_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_27_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_28_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_29_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\november\delhi_30_11_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_01_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_02_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_03_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_04_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_05_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_06_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_07_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_08_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_09_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_10_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_11_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_12_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_13_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_14_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_15_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_16_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_17_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_18_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_19_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_20_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_21_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_22_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_23_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_24_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_25_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_26_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_27_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_28_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_29_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_30_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\october\delhi_31_10_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_01_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_02_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_03_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_04_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_05_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_06_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_07_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_08_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_09_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_10_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_11_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_12_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_13_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_14_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_15_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_16_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_17_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_18_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_19_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_20_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_21_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_22_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_23_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_24_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_25_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_26_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_27_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_28_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_29_09_2022.csv
# Processing: D:\DelhiElectricity\delhi_dispatch\data\september\delhi_30_09_2022.csv
# C:\Users\Suraj\AppData\Local\Temp\ipykernel_11208\583162296.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged_df = pd.concat(all_data, ignore_index=True)
# Merged CSV saved as merged_output.csv

# %% [markdown]
# ### Columns Explanation
# ### TIMESLOT – The timestamp (HH:MM format) indicating when the data was recorded.
# ### DELHI – The total electricity load/consumption (in MegaWatts, MW) for the entire Delhi region.
# ### BRPL (BSES Rajdhani Power Limited) – Electricity load for the area covered by BRPL.
# ### BYPL (BSES Yamuna Power Limited) – Electricity load for the area covered by BYPL.
# ### NDPL (North Delhi Power Limited, now Tata Power Delhi Distribution Ltd - TPDDL) – Electricity load for North Delhi.
# ### NDMC (New Delhi Municipal Council) – Electricity consumption for the NDMC region, which covers central Delhi areas.
# ### MES (Military Engineering Services) – Electricity consumption for the military or defense-related establishments.

# %%
import pandas as pd
df = pd.read_csv('merged_output.csv')

# %%
df.head()
# Out:
#   TIMESLOT    DELHI     BRPL    BYPL     NDPL    NDMC    MES
# 0    00:00  4055.22  1679.45  909.68  1258.12  147.86  21.59
# 1    00:05  4027.10  1683.49  902.38  1235.49  146.11  21.29
# 2    00:10  4034.82  1695.21  905.22  1232.09  144.58  21.31
# 3    00:15  4005.54  1682.40  895.36  1224.13  144.39  21.25
# 4    00:20  3989.53  1673.81  885.83  1225.06  144.43  21.14

# %%
import pandas as pd

# List of holiday dates
holiday_dates = [
    '2024-04-17', '2024-04-21', '2024-04-29',
    '2024-05-23', '2024-06-17', '2024-07-17',
    '2024-08-15', '2024-08-26', '2024-09-16',
    '2024-10-02', '2024-10-12', '2024-10-31',
    '2024-11-15', '2024-12-25'
]

# Create DataFrame
holidays_df = pd.DataFrame({
    'DATE': pd.to_datetime(holiday_dates),
    'HOLIDAY': 'Holiday'
})

# %%
holidays_df
# Out:
#          DATE  HOLIDAY
# 0  2024-04-17  Holiday
# 1  2024-04-21  Holiday
# 2  2024-04-29  Holiday
# 3  2024-05-23  Holiday
# 4  2024-06-17  Holiday
# 5  2024-07-17  Holiday
# 6  2024-08-15  Holiday
# 7  2024-08-26  Holiday
# 8  2024-09-16  Holiday
# 9  2024-10-02  Holiday
# 10 2024-10-12  Holiday
# 11 2024-10-31  Holiday
# 12 2024-11-15  Holiday
# 13 2024-12-25  Holiday

# %%
print("Load Data Columns:", df.columns)
print("Holiday Data Columns:", holidays_df.columns)
# Out:
# Load Data Columns: Index(['TIMESLOT', 'DELHI', 'BRPL', 'BYPL', 'NDPL', 'NDMC', 'MES'], dtype='object')
# Holiday Data Columns: Index(['DATE', 'HOLIDAY'], dtype='object')

# %%
import pandas as pd

# List of public holidays in India (you can modify based on Delhi holidays)
holidays_2024 = [
    "2024-01-26",  # Republic Day
    "2024-03-25",  # Holi
    "2024-04-10",  # Eid-ul-Fitr
    "2024-04-17",  # Ram Navami
    "2024-05-01",  # Labour Day
    "2024-08-15",  # Independence Day
    "2024-10-02",  # Gandhi Jayanti
    "2024-11-01",  # Diwali
    "2024-12-25",  # Christmas
]

# Convert list to DataFrame
holidays_df = pd.DataFrame({'DATE': pd.to_datetime(holidays_2024), 'HOLIDAY': 'Holiday'})

# Save it (optional)
holidays_df.to_csv('holidays.csv', index=False)

# %%
import pandas as pd

# Load merged electricity load data
load_data_df = pd.read_csv('merged_output.csv')

# Check if 'DATE' column exists, if not, create it
if 'DATE' not in load_data_df.columns:
    start_date = pd.to_datetime("2024-04-01")  # Change based on actual start date
    num_rows = len(load_data_df)
    
    # Ensure the number of time slots is divisible by 288
    num_days = num_rows // 288  # Full days
    remaining_rows = num_rows % 288  # Remaining rows after full days
    
    # Create a range of dates for the full days
    dates = pd.date_range(start=start_date, periods=num_days, freq='D')
    
    # Repeat each date for 288 time slots and convert it into a Pandas Series
    repeated_dates = pd.Series(dates.repeat(288).values)
    
    # If there are remaining rows, add them using the last date
    if remaining_rows > 0:
        remaining_dates = pd.Series([dates[-1]] * remaining_rows)
        repeated_dates = pd.concat([repeated_dates, remaining_dates], ignore_index=True)

    # Assign to DataFrame
    load_data_df['DATE'] = repeated_dates.values  # Ensure it matches the index properly

# Convert DATE column to datetime format
load_data_df['DATE'] = pd.to_datetime(load_data_df['DATE'])

# Create holiday DataFrame
holidays_2024 = [
    "2024-01-26", "2024-03-25", "2024-04-10", "2024-04-17",
    "2024-05-01", "2024-08-15", "2024-10-02", "2024-11-01", "2024-12-25"
]
holidays_df = pd.DataFrame({'DATE': pd.to_datetime(holidays_2024), 'HOLIDAY': 'Holiday'})

# Merge with holiday data
merged_df = pd.merge(load_data_df, holidays_df, on='DATE', how='left')

# Fill missing holidays with 'Not a Holiday'
merged_df['HOLIDAY'].fillna('Not a Holiday', inplace=True)

# Save the final merged data
merged_df.to_csv('final_merged_output.csv', index=False)

print("✅ Data merged successfully! Check 'final_merged_output.csv'.")
# Out:
# C:\Users\Suraj\AppData\Local\Temp\ipykernel_11208\1118072999.py:43: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['HOLIDAY'].fillna('Not a Holiday', inplace=True)
# ✅ Data merged successfully! Check 'final_merged_output.csv'.

# %%
import pandas as pd
df = pd.read_csv('final_merged_output.csv')
df.head()
# Out:
#   TIMESLOT    DELHI     BRPL    BYPL     NDPL    NDMC    MES        DATE  \
# 0    00:00  4055.22  1679.45  909.68  1258.12  147.86  21.59  2024-04-01
# 1    00:05  4027.10  1683.49  902.38  1235.49  146.11  21.29  2024-04-01
# 2    00:10  4034.82  1695.21  905.22  1232.09  144.58  21.31  2024-04-01
# 3    00:15  4005.54  1682.40  895.36  1224.13  144.39  21.25  2024-04-01
# 4    00:20  3989.53  1673.81  885.83  1225.06  144.43  21.14  2024-04-01
#
#          HOLIDAY
# 0  Not a Holiday
# 1  Not a Holiday
# 2  Not a Holiday
# 3  Not a Holiday
# 4  Not a Holiday

# %%
df.isnull().sum()
# Out:
# TIMESLOT    0
# DELHI       0
# BRPL        0
# BYPL        0
# NDPL        0
# NDMC        0
# MES         0
# DATE        0
# HOLIDAY     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import pandas as pd

# Sample DataFrame
data = {
    "HOLIDAY": ["Not a Holiday", "Not a Holiday", "Holiday", "Not a Holiday", "Holiday"]
}


# Binary Encoding: Convert "Holiday" to 1 and "Not a Holiday" to 0
df["HOLIDAY"] = df["HOLIDAY"].apply(lambda x: 1 if x == "Holiday" else 0)

print(df)
# Out:
#       TIMESLOT    DELHI     BRPL     BYPL     NDPL    NDMC    MES        DATE  \
# 0        00:00  4055.22  1679.45   909.68  1258.12  147.86  21.59  2024-04-01
# 1        00:05  4027.10  1683.49   902.38  1235.49  146.11  21.29  2024-04-01
# 2        00:10  4034.82  1695.21   905.22  1232.09  144.58  21.31  2024-04-01
# 3        00:15  4005.54  1682.40   895.36  1224.13  144.39  21.25  2024-04-01
# 4        00:20  3989.53  1673.81   885.83  1225.06  144.43  21.14  2024-04-01
# ...        ...      ...      ...      ...      ...     ...    ...         ...
# 92263    23:30  4659.12  1956.94  1021.06  1425.59  180.09  23.88  2025-02-14
# 92264    23:35  4654.94  1938.14  1030.45  1438.86  179.84  23.82  2025-02-14
# 92265    23:40  4633.86  1932.95  1023.13  1430.46  179.58  23.67  2025-02-14
# 92266    23:45  4618.72  1927.55  1024.91  1419.31  179.48  23.69  2025-02-14
# 92267    23:50  4624.38  1920.67  1032.33  1425.04  174.90  23.64  2025-02-14
#
#        HOLIDAY
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 92263        0
# 92264        0
# 92265        0
# 92266        0
# 92267        0
#
# [92268 rows x 9 columns]

# %%
df['HOLIDAY'].value_counts()
# Out:
# HOLIDAY
# 0    90252
# 1     2016
# Name: count, dtype: int64

# %%
df['DELHI'].value_counts()
# Out:
# DELHI
# 3695.87    295
# 4721.27      5
# 3247.59      4
# 3196.64      4
# 3906.36      4
#           ...
# 4545.48      1
# 4541.92      1
# 4581.08      1
# 4589.91      1
# 3956.49      1
# Name: count, Length: 83463, dtype: int64

# %%
import pandas as pd
import numpy as np
import joblib
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error


# Convert DATE & TIMESLOT to Datetime
df['DATETIME'] = pd.to_datetime(df['DATE'] + ' ' + df['TIMESLOT'])
df = df.drop(columns=['DATE', 'TIMESLOT'])  # Drop original date columns

# Extract Time Features
df['hour'] = df['DATETIME'].dt.hour
df['day'] = df['DATETIME'].dt.day
df['month'] = df['DATETIME'].dt.month
df['weekday'] = df['DATETIME'].dt.weekday
df['weekend'] = (df['weekday'] >= 5).astype(int)  # 1 for Sat/Sun, else 0

# Drop Unneeded Columns
df = df.drop(columns=['DATETIME', 'HOLIDAY'])

# Define Target (DELHI MW Load)
X = df.drop(columns=['DELHI'])  # Features
y = df['DELHI']  # Target

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=False)

# Train XGBoost Model
xgb_model = XGBRegressor(n_estimators=500, learning_rate=0.05, max_depth=8, subsample=0.8, colsample_bytree=0.8)
xgb_model.fit(X_train, y_train)

# Save Model
joblib.dump(xgb_model, "electricity_load_xgb.pkl")

# Predictions
y_pred = xgb_model.predict(X_test)

# Evaluate Model
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"📊 MAE: {mae:.2f}, RMSE: {rmse:.2f}")

# --- Predict Next 7 Days ---
future_dates = pd.date_range(start=pd.to_datetime("2025-02-07"), periods=7*288, freq="5T")  # Adjust start date

# Generate Future Features
future_df = pd.DataFrame({"DATETIME": future_dates})
future_df["hour"] = future_df["DATETIME"].dt.hour
future_df["day"] = future_df["DATETIME"].dt.day
future_df["month"] = future_df["DATETIME"].dt.month
future_df["weekday"] = future_df["DATETIME"].dt.weekday
future_df["weekend"] = (future_df["weekday"] >= 5).astype(int)

# Ensure future_X has **exact same columns** as X_train
missing_cols = set(X_train.columns) - set(future_df.columns)
for col in missing_cols:
    future_df[col] = 0  # Add missing columns with default value

# Ensure Column Order Matches Training Data
future_X = future_df[X_train.columns]

# Predict Next 7 Days Load
future_predictions = xgb_model.predict(future_X)

# Save Predictions
future_df["Predicted Load (MW)"] = future_predictions
future_df.to_csv("future_load_predictions.csv", index=False)

print("✅ Future 7-Day Predictions Saved: future_load_predictions.csv")
# Out:
# 📊 MAE: 7.46, RMSE: 9.96
# ✅ Future 7-Day Predictions Saved: future_load_predictions.csv
# C:\Users\Suraj\AppData\Local\Temp\ipykernel_11208\1840212218.py:46: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   future_dates = pd.date_range(start=pd.to_datetime("2025-02-07"), periods=7*288, freq="5T")  # Adjust start date

# %%
df = pd.read_csv('future_load_predictions.csv')
df.head(10)
# Out:
#               DATETIME  hour  day  month  weekday  weekend  BYPL  NDMC  MES  \
# 0  2025-02-07 00:00:00     0    7      2        4        0     0     0    0
# 1  2025-02-07 00:05:00     0    7      2        4        0     0     0    0
# 2  2025-02-07 00:10:00     0    7      2        4        0     0     0    0
# 3  2025-02-07 00:15:00     0    7      2        4        0     0     0    0
# 4  2025-02-07 00:20:00     0    7      2        4        0     0     0    0
# 5  2025-02-07 00:25:00     0    7      2        4        0     0     0    0
# 6  2025-02-07 00:30:00     0    7      2        4        0     0     0    0
# 7  2025-02-07 00:35:00     0    7      2        4        0     0     0    0
# 8  2025-02-07 00:40:00     0    7      2        4        0     0     0    0
# 9  2025-02-07 00:45:00     0    7      2        4        0     0     0    0
#
#    BRPL  NDPL  Predicted Load (MW)
# 0     0     0            1290.2053
# 1     0     0            1290.2053
# 2     0     0            1290.2053
# 3     0     0            1290.2053
# 4     0     0            1290.2053
# 5     0     0            1290.2053
# 6     0     0            1290.2053
# 7     0     0            1290.2053
# 8     0     0            1290.2053
# 9     0     0            1290.2053

# %%
# Load the trained model
xgb_model_loaded = joblib.load("electricity_load_xgb.pkl")

# %%
feature_names = xgb_model_loaded.feature_names_in_
print(feature_names)
# Out:
# ['BRPL' 'BYPL' 'NDPL' 'NDMC' 'MES' 'hour' 'day' 'month' 'weekday'
#  'weekend']

# %%
sample_data = pd.DataFrame({
    'BRPL': [1200],  # Replace with actual values
    'BYPL': [900],
    'NDPL': [1100],
    'NDMC': [700],
    'MES': [500],
    'hour': [12],  # Example: 12 PM
    'day': [7],  # Example: 7th of the month
    'month': [2],  # Example: February
    'weekday': [3],  # Example: Wednesday (if Monday=0, Sunday=6)
    'weekend': [0]  # 0 if it's a weekday, 1 if it's a weekend
})

# Predict using the trained model
predicted_load = xgb_model_loaded.predict(sample_data)

# Print the prediction
print(f"Predicted Electricity Load (MW): {predicted_load[0]}")
# Out:
# Predicted Electricity Load (MW): 3615.858154296875

# %%
xgb_model.score(X_test,y_test)*100
# Out:
# 99.97070539195154

# %%
xgb_model.score(X_train,y_train)*100
# Out:
# 99.99736531394689

# %%
import pandas as pd

# Load dataset
data = pd.read_csv("Final_data_cleaned.csv")

# Print all available columns
print("🔍 Available Columns in Dataset:")
print(data.columns.tolist())  # Check actual column names
# Out:
# 🔍 Available Columns in Dataset:
# ['Unnamed: 0', 'TIMESLOT', 'DELHI', 'BRPL', 'BYPL', 'NDPL', 'NDMC', 'MES', 'Hour', 'Day_x', 'Month_x', 'Day_of_Week_x', 'Weekend_x', 'DELHI_rolling_mean', 'Date', 'Day_y', 'Month_y', 'Day_of_Week_y', 'Weekend_y', 'Public_Holiday']

# %%
FEATURES = ['BRPL', 'BYPL', 'NDPL', 'NDMC', 'MES', 'Hour', 'Day_x', 'Month_x', 'Day_of_Week_x', 'Weekend_x']  
TARGET = "DELHI"  # Assuming 'DELHI' represents MW Load

# Load dataset
data = pd.read_csv("Final_data_cleaned.csv")

# Select correct features
X = data[FEATURES]
y_true = data[TARGET]

# Verify selection
print(X.head())
# Out:
#        BRPL      BYPL      NDPL      NDMC       MES  Hour  Day_x  Month_x  \
# 0 -0.016540  0.029359  0.006544 -0.533180 -0.792390     0     11        1
# 1 -0.044611 -0.005758 -0.026276 -0.561131 -0.779217     0     11        1
# 2 -0.065108 -0.031217 -0.048859 -0.582992 -0.798378     0     11        1
# 3 -0.073083 -0.039490 -0.052965 -0.584866 -0.823526     0     11        1
# 4 -0.091832 -0.048877 -0.062945 -0.580806 -0.809155     0     11        1
#
#    Day_of_Week_x  Weekend_x
# 0              5          1
# 1              5          1
# 2              5          1
# 3              5          1
# 4              5          1

# %%
# Rename test dataset columns to match training
X = X.rename(columns={
    "Hour": "hour", 
    "Day_x": "day", 
    "Month_x": "month", 
    "Day_of_Week_x": "weekday", 
    "Weekend_x": "weekend"
})

# %%
y_pred = xgb_model.predict(X)

# %%
print("y_true range:", y_true.min(), "-", y_true.max())
print("y_pred range:", y_pred.min(), "-", y_pred.max())
# Out:
# y_true range: -2.144274708355064 - 2.854564127151242
# y_pred range: 1293.3759 - 1297.0521
